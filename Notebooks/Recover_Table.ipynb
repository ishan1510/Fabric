# %%
# Run this if you are using the default environment
# %pip install semantic-link-labs

# %%
# %%sql
# CREATE TABLE emp (id int, name varchar(30))USING DELTA;
# Out:
# StatementMeta(, 1f8a5b5c-0484-4abb-bf65-bc271d2522e5, 4, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# INSERT INTO emp VALUES (1, 'John'),(2, 'nick'),(3,'joe');
# Out:
# StatementMeta(, 1f8a5b5c-0484-4abb-bf65-bc271d2522e5, 5, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>

# %% [markdown]
# ### **Read data from emp table**

# %%
# %%sql
#
# SELECT * FROM API_Lakehouse.emp LIMIT 1000
# Out:
# StatementMeta(, 6218923a-a17d-4042-bf73-438caa70dd08, 21, Finished, Available, Finished)
# <Spark SQL result set with 3 rows and 2 fields>

# %% [markdown]
# ### **Drop emp table**

# %%
# %%sql
# DROP TABLE emp
# Out:
# StatementMeta(, 1f8a5b5c-0484-4abb-bf65-bc271d2522e5, 6, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>

# %% [markdown]
# ### **Restore emp table**

# %%
import sempy_labs.lakehouse as lake

lakehouse = 'API_Lakehouse' # Enter the name or ID of the lakehouse
workspace = 'Fabric_API_Test' # Enter the name or ID of the workspace in which the lakehouse exists

# Example 1: Recover a delta table
lake.recover_lakehouse_object(file_path='Tables/emp', lakehouse=lakehouse, workspace=workspace)
# Out:
# StatementMeta(, 6218923a-a17d-4042-bf73-438caa70dd08, 20, Finished, Available, Finished)
# ⌛ Restoring the '168b0f0a-4f18-43f5-b40e-63154b2e95ee/Tables/emp' blob...
# 🟢 The '168b0f0a-4f18-43f5-b40e-63154b2e95ee/Tables/emp' blob has been restored.
